# %% [markdown]
# <a href="https://colab.research.google.com/github/Kartikey9936/Classical-ML/blob/main/API_to_JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=219e144f050ec31234f3f1d4c46b1915&language=en-US&page=1')

# %%
data = response.json()['results']

# %%
df = pd.DataFrame(data)
df.shape
# Out:
# (20, 15)

# %%
df[['id','title','overview','release_date','popularity','vote_average']]
# Out:
#          id                                          title  \
# 0   1007757                                        Swapped
# 1       278                       The Shawshank Redemption
# 2       238                                  The Godfather
# 3    687163                              Project Hail Mary
# 4       240                          The Godfather Part II
# 5       424                               Schindler's List
# 6       389                                   12 Angry Men
# 7       129                                  Spirited Away
# 8       155                                The Dark Knight
# 9   1330021                    Remarkably Bright Creatures
# 10    19404                    Dilwale Dulhania Le Jayenge
# 11      497                                 The Green Mile
# 12      122  The Lord of the Rings: The Return of the King
# 13  1181678                          ¿Quieres ser mi hijo?
# 14   496243                                       Parasite
# ...

# %%
df = pd.DataFrame() #it will create a empty

# %%
for i in range(1,500):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=219e144f050ec31234f3f1d4c46b1915&language=en-US&page={}'.format(i))
    response_data = response.json()

# %%
df
# Out:
#        adult                     backdrop_path            genre_ids       id  \
# 0      False   /zMwhWailP1WY7sb6AoE6b8ugoy.jpg  [12, 16, 10751, 14]  1007757
# 1      False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg             [18, 80]      278
# 2      False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg             [18, 80]      238
# 3      False  /2I1OFQJ0L9T0dpU6FobKFWV2PxX.jpg            [878, 12]   687163
# 4      False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg             [18, 80]      240
# ...      ...                               ...                  ...      ...
# 29995    NaN                               NaN                  NaN   339530
# 29996    NaN                               NaN                  NaN    54054
# 29997    NaN                               NaN                  NaN     9879
# 29998    NaN                               NaN                  NaN   560144
# 29999    NaN                               NaN                  NaN   520360
#
# ...
